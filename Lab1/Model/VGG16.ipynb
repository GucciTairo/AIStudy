# %% [markdown]
# Here is the code use VGG16 with cat dog and horse use for training dataset. After training and receive accuracy. I see that all model work well.
# I've already defined dataset with .npy format, have float32 and normalization with [0,1] to enhances learning of model.
#     -> Not even using some tool like squeeze blocks,..
#     -> Using fully connected layers with multiple layers from 1024-512-256 layers in hidden.
#     -> I receive the best accuracy when i test the model on test with accuracy is 98%.
#     -> I think that using too much hidden layers -> cost too much computation time
#
# ![image.png](attachment:image.png)
#
# For dynamically adjust learning rate i use ReduceLROnPlateau. For reduce the lr when the model stop improvings. So far, it can use to apply for fine tune

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
#from data_loader import load_npy_files, create_tf_dataset  # Import dataset utilities
# Out:
# 2025-03-11 17:46:23.097756: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-11 17:46:23.114239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741689983.129254  143728 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741689983.133777  143728 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-11 17:46:23.151332: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)  # Prevents memory overflow
        print(f"Using GPU: {gpus[0]}")
    except RuntimeError as e:
        print(e)
else:
    print("No GPU found, using CPU.")
# Out:
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled.")
    except RuntimeError as e:
        print(e)
# Out:
# GPU memory growth enabled.

# %%
# Load dataset paths
X_train_path = "/media/tairo/Storages/DataSetAnimals/.npy format/X_train.npy"
y_train_path = "/media/tairo/Storages/DataSetAnimals/.npy format/y_train.npy"
X_val_path = "/media/tairo/Storages/DataSetAnimals/.npy format/X_val.npy"
y_val_path = "/media/tairo/Storages/DataSetAnimals/.npy format/y_val.npy"

# %%
# Load dataset
X_train = np.load(X_train_path)
y_train = np.load(y_train_path)
X_val = np.load(X_val_path)
y_val = np.load(y_val_path)

# %%
# Detect number of classes
class_indices = np.unique(y_train)
num_classes = len(class_indices)

# Create a class mapping (assumes class labels are integers: 0, 1, 2, ...)
class_map = {idx: f"Class_{idx}" for idx in class_indices}

# %%
# Convert labels to one-hot encoding
num_classes = len(np.unique(y_train))  
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_val = tf.keras.utils.to_categorical(y_val, num_classes)

# %%
# Print class information
print(f"Detected {num_classes} classes:", class_map)
print("\nTrain Labels:", np.unique(np.argmax(y_train, axis=1), return_counts=True))
print("Validation Labels:", np.unique(np.argmax(y_val, axis=1), return_counts=True))
# Out:
# Detected 3 classes: {np.int64(0): 'Class_0', np.int64(1): 'Class_1', np.int64(2): 'Class_2'}
#
# Train Labels: (array([0, 1, 2]), array([700, 700, 700]))
# Validation Labels: (array([0, 1, 2]), array([200, 200, 200]))

# %%
# Define batch size (reduce to fit in GPU memory)
BATCH_SIZE = 4  # Reduce from 32 to avoid GPU memory overflow

# Convert NumPy arrays into TensorFlow dataset (streaming)
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(len(X_train)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1741689985.948096  143728 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1919 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Function to build VGG16 model
def build_vgg16(input_shape=(224, 224, 3), num_classes=4, reg_strength=0.0005):
    # Load VGG16 Pretrained Model (Without Fully Connected Top Layers)
    base_model = VGG16(input_shape=input_shape, include_top=False, weights="imagenet")
    
    # Freeze base model layers initially
    base_model.trainable = False  
    
    # Extract features from VGG16
    x = base_model.output  
    x = GlobalAveragePooling2D()(x)  # Global Average Pooling

    # Fully Connected Layers (1024 → 512 → 256)
    x = Dense(256, kernel_regularizer=l2(reg_strength))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)

    x = Dense(128, kernel_regularizer=l2(reg_strength))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.4)(x)

    x = Dense(64, kernel_regularizer=l2(reg_strength))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)

    # Final Classification Layer
    outputs = Dense(num_classes, activation='softmax', dtype="float32", kernel_regularizer=l2(reg_strength))(x)

    # Build Model
    model = Model(inputs=base_model.input, outputs=outputs)
    return model

# %%
# Build the VGG16 model
model = build_vgg16(input_shape=(224, 224, 3), num_classes=num_classes)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %%
# Define callbacks
BEST_MODEL_PATH = "best_model(3).keras"

checkpoint = ModelCheckpoint(
    BEST_MODEL_PATH, monitor="val_loss", save_best_only=True, save_weights_only=False, mode="min", verbose=1
)

early_stopping = EarlyStopping(
    monitor="val_loss", patience=20, restore_best_weights=True, mode="min"
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=5, verbose=1, min_lr=1e-7
)

# %%
with tf.device('/GPU:0'):  # Forces GPU usage
    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=200,  # Increase if needed
        callbacks=[checkpoint, early_stopping, reduce_lr]
    )
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741689990.308897  143985 service.cc:148] XLA service 0x740dd0015c20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741689990.308914  143985 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-03-11 17:46:30.365440: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1741689990.669741  143985 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-03-11 17:46:32.211951: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 114.14MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:32.249369: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 114.14MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:32.359804: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 114.14MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:32.359841: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 114.14MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:32.487387: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 114.14MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:32.594966: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 37.25MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:32.594999: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 898.56MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:32.874972: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 347.88MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:33.487586: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 459.25MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 17:46:34.011519: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 245.50MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#   5/525 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.3475 - loss: 2.2150
# I0000 00:00:1741689996.358149  143985 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5668 - loss: 1.8114
# Epoch 1: val_loss improved from inf to 1.06910, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 53ms/step - accuracy: 0.5670 - loss: 1.8110 - val_accuracy: 0.9500 - val_loss: 1.0691 - learning_rate: 1.0000e-04
# Epoch 2/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7580 - loss: 1.4325
# Epoch 2: val_loss improved from 1.06910 to 0.95018, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.7580 - loss: 1.4324 - val_accuracy: 0.9717 - val_loss: 0.9502 - learning_rate: 1.0000e-04
# Epoch 3/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8084 - loss: 1.3422
# Epoch 3: val_loss improved from 0.95018 to 0.93051, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8084 - loss: 1.3422 - val_accuracy: 0.9733 - val_loss: 0.9305 - learning_rate: 1.0000e-04
# Epoch 4/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8168 - loss: 1.2879
# Epoch 4: val_loss improved from 0.93051 to 0.92053, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8168 - loss: 1.2879 - val_accuracy: 0.9733 - val_loss: 0.9205 - learning_rate: 1.0000e-04
# Epoch 5/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8348 - loss: 1.2460
# Epoch 5: val_loss improved from 0.92053 to 0.90643, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8349 - loss: 1.2460 - val_accuracy: 0.9750 - val_loss: 0.9064 - learning_rate: 1.0000e-04
# Epoch 6/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8762 - loss: 1.1854
# Epoch 6: val_loss improved from 0.90643 to 0.90141, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8762 - loss: 1.1854 - val_accuracy: 0.9767 - val_loss: 0.9014 - learning_rate: 1.0000e-04
# Epoch 7/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8533 - loss: 1.2164
# Epoch 7: val_loss improved from 0.90141 to 0.89059, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8533 - loss: 1.2164 - val_accuracy: 0.9783 - val_loss: 0.8906 - learning_rate: 1.0000e-04
# Epoch 8/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8478 - loss: 1.2597
# Epoch 8: val_loss improved from 0.89059 to 0.87370, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8478 - loss: 1.2597 - val_accuracy: 0.9800 - val_loss: 0.8737 - learning_rate: 1.0000e-04
# Epoch 9/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8776 - loss: 1.1526
# Epoch 9: val_loss improved from 0.87370 to 0.86606, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8776 - loss: 1.1526 - val_accuracy: 0.9800 - val_loss: 0.8661 - learning_rate: 1.0000e-04
# Epoch 10/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8809 - loss: 1.1414
# Epoch 10: val_loss improved from 0.86606 to 0.85785, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8810 - loss: 1.1414 - val_accuracy: 0.9817 - val_loss: 0.8579 - learning_rate: 1.0000e-04
# Epoch 11/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8689 - loss: 1.1307
# Epoch 11: val_loss improved from 0.85785 to 0.85028, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8689 - loss: 1.1307 - val_accuracy: 0.9833 - val_loss: 0.8503 - learning_rate: 1.0000e-04
# Epoch 12/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8998 - loss: 1.0830
# Epoch 12: val_loss improved from 0.85028 to 0.84262, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8998 - loss: 1.0830 - val_accuracy: 0.9800 - val_loss: 0.8426 - learning_rate: 1.0000e-04
# Epoch 13/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8895 - loss: 1.1088
# Epoch 13: val_loss improved from 0.84262 to 0.84130, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8895 - loss: 1.1088 - val_accuracy: 0.9867 - val_loss: 0.8413 - learning_rate: 1.0000e-04
# Epoch 14/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8967 - loss: 1.1274
# Epoch 14: val_loss improved from 0.84130 to 0.82809, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8967 - loss: 1.1274 - val_accuracy: 0.9850 - val_loss: 0.8281 - learning_rate: 1.0000e-04
# Epoch 15/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9023 - loss: 1.0705
# Epoch 15: val_loss improved from 0.82809 to 0.82566, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9023 - loss: 1.0705 - val_accuracy: 0.9817 - val_loss: 0.8257 - learning_rate: 1.0000e-04
# Epoch 16/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9162 - loss: 1.0220
# Epoch 16: val_loss improved from 0.82566 to 0.82023, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9162 - loss: 1.0220 - val_accuracy: 0.9867 - val_loss: 0.8202 - learning_rate: 1.0000e-04
# Epoch 17/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9158 - loss: 1.0044
# Epoch 17: val_loss improved from 0.82023 to 0.80123, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9158 - loss: 1.0045 - val_accuracy: 0.9850 - val_loss: 0.8012 - learning_rate: 1.0000e-04
# Epoch 18/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9059 - loss: 1.0425
# Epoch 18: val_loss improved from 0.80123 to 0.80091, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9059 - loss: 1.0425 - val_accuracy: 0.9900 - val_loss: 0.8009 - learning_rate: 1.0000e-04
# Epoch 19/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9053 - loss: 1.0536
# Epoch 19: val_loss improved from 0.80091 to 0.79037, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9053 - loss: 1.0536 - val_accuracy: 0.9900 - val_loss: 0.7904 - learning_rate: 1.0000e-04
# Epoch 20/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9108 - loss: 1.0058
# Epoch 20: val_loss improved from 0.79037 to 0.78245, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9108 - loss: 1.0057 - val_accuracy: 0.9900 - val_loss: 0.7824 - learning_rate: 1.0000e-04
# Epoch 21/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8952 - loss: 1.0863
# Epoch 21: val_loss did not improve from 0.78245
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.8952 - loss: 1.0862 - val_accuracy: 0.9883 - val_loss: 0.7828 - learning_rate: 1.0000e-04
# Epoch 22/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9028 - loss: 1.0266
# Epoch 22: val_loss did not improve from 0.78245
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9029 - loss: 1.0265 - val_accuracy: 0.9883 - val_loss: 0.7864 - learning_rate: 1.0000e-04
# Epoch 23/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9220 - loss: 0.9514
# Epoch 23: val_loss improved from 0.78245 to 0.76522, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9220 - loss: 0.9514 - val_accuracy: 0.9867 - val_loss: 0.7652 - learning_rate: 1.0000e-04
# Epoch 24/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9205 - loss: 0.9765
# Epoch 24: val_loss improved from 0.76522 to 0.76118, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9206 - loss: 0.9765 - val_accuracy: 0.9883 - val_loss: 0.7612 - learning_rate: 1.0000e-04
# Epoch 25/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9155 - loss: 0.9694
# Epoch 25: val_loss did not improve from 0.76118
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9155 - loss: 0.9694 - val_accuracy: 0.9833 - val_loss: 0.7617 - learning_rate: 1.0000e-04
# Epoch 26/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9406 - loss: 0.9029
# Epoch 26: val_loss improved from 0.76118 to 0.74621, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9406 - loss: 0.9030 - val_accuracy: 0.9800 - val_loss: 0.7462 - learning_rate: 1.0000e-04
# Epoch 27/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9213 - loss: 0.9334
# Epoch 27: val_loss improved from 0.74621 to 0.73928, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9213 - loss: 0.9334 - val_accuracy: 0.9850 - val_loss: 0.7393 - learning_rate: 1.0000e-04
# Epoch 28/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9345 - loss: 0.8984
# Epoch 28: val_loss improved from 0.73928 to 0.72880, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9344 - loss: 0.8984 - val_accuracy: 0.9850 - val_loss: 0.7288 - learning_rate: 1.0000e-04
# Epoch 29/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9335 - loss: 0.8885
# Epoch 29: val_loss improved from 0.72880 to 0.72117, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9335 - loss: 0.8885 - val_accuracy: 0.9867 - val_loss: 0.7212 - learning_rate: 1.0000e-04
# Epoch 30/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9208 - loss: 0.9083
# Epoch 30: val_loss did not improve from 0.72117
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9208 - loss: 0.9083 - val_accuracy: 0.9867 - val_loss: 0.7342 - learning_rate: 1.0000e-04
# Epoch 31/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9310 - loss: 0.8823
# Epoch 31: val_loss did not improve from 0.72117
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9310 - loss: 0.8822 - val_accuracy: 0.9850 - val_loss: 0.7255 - learning_rate: 1.0000e-04
# Epoch 32/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9319 - loss: 0.8806
# Epoch 32: val_loss improved from 0.72117 to 0.70802, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9319 - loss: 0.8806 - val_accuracy: 0.9883 - val_loss: 0.7080 - learning_rate: 1.0000e-04
# Epoch 33/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9205 - loss: 0.8989
# Epoch 33: val_loss did not improve from 0.70802
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9205 - loss: 0.8989 - val_accuracy: 0.9800 - val_loss: 0.7118 - learning_rate: 1.0000e-04
# Epoch 34/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9328 - loss: 0.8737
# Epoch 34: val_loss improved from 0.70802 to 0.70332, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9328 - loss: 0.8737 - val_accuracy: 0.9817 - val_loss: 0.7033 - learning_rate: 1.0000e-04
# Epoch 35/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9150 - loss: 0.9014
# Epoch 35: val_loss improved from 0.70332 to 0.69161, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9150 - loss: 0.9013 - val_accuracy: 0.9817 - val_loss: 0.6916 - learning_rate: 1.0000e-04
# Epoch 36/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9327 - loss: 0.8557
# Epoch 36: val_loss improved from 0.69161 to 0.68123, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9327 - loss: 0.8557 - val_accuracy: 0.9817 - val_loss: 0.6812 - learning_rate: 1.0000e-04
# Epoch 37/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9352 - loss: 0.8520
# Epoch 37: val_loss improved from 0.68123 to 0.67365, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9352 - loss: 0.8520 - val_accuracy: 0.9883 - val_loss: 0.6736 - learning_rate: 1.0000e-04
# Epoch 38/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9461 - loss: 0.8097
# Epoch 38: val_loss improved from 0.67365 to 0.66145, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9461 - loss: 0.8097 - val_accuracy: 0.9900 - val_loss: 0.6615 - learning_rate: 1.0000e-04
# Epoch 39/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9422 - loss: 0.8159
# Epoch 39: val_loss improved from 0.66145 to 0.65835, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9422 - loss: 0.8159 - val_accuracy: 0.9850 - val_loss: 0.6584 - learning_rate: 1.0000e-04
# Epoch 40/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9515 - loss: 0.7789
# Epoch 40: val_loss improved from 0.65835 to 0.65626, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9515 - loss: 0.7790 - val_accuracy: 0.9833 - val_loss: 0.6563 - learning_rate: 1.0000e-04
# Epoch 41/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9169 - loss: 0.8531
# Epoch 41: val_loss improved from 0.65626 to 0.65408, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9169 - loss: 0.8531 - val_accuracy: 0.9867 - val_loss: 0.6541 - learning_rate: 1.0000e-04
# Epoch 42/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9404 - loss: 0.7879
# Epoch 42: val_loss improved from 0.65408 to 0.63392, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9404 - loss: 0.7879 - val_accuracy: 0.9850 - val_loss: 0.6339 - learning_rate: 1.0000e-04
# Epoch 43/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9453 - loss: 0.8070
# Epoch 43: val_loss improved from 0.63392 to 0.62423, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9453 - loss: 0.8070 - val_accuracy: 0.9917 - val_loss: 0.6242 - learning_rate: 1.0000e-04
# Epoch 44/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9506 - loss: 0.7341
# Epoch 44: val_loss did not improve from 0.62423
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9506 - loss: 0.7341 - val_accuracy: 0.9850 - val_loss: 0.6250 - learning_rate: 1.0000e-04
# Epoch 45/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9364 - loss: 0.7901
# Epoch 45: val_loss improved from 0.62423 to 0.61610, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9364 - loss: 0.7901 - val_accuracy: 0.9883 - val_loss: 0.6161 - learning_rate: 1.0000e-04
# Epoch 46/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9134 - loss: 0.8445
# Epoch 46: val_loss improved from 0.61610 to 0.61331, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9135 - loss: 0.8445 - val_accuracy: 0.9817 - val_loss: 0.6133 - learning_rate: 1.0000e-04
# Epoch 47/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9369 - loss: 0.7972
# Epoch 47: val_loss improved from 0.61331 to 0.60624, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9369 - loss: 0.7972 - val_accuracy: 0.9850 - val_loss: 0.6062 - learning_rate: 1.0000e-04
# Epoch 48/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9386 - loss: 0.7707
# Epoch 48: val_loss improved from 0.60624 to 0.60197, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9386 - loss: 0.7707 - val_accuracy: 0.9867 - val_loss: 0.6020 - learning_rate: 1.0000e-04
# Epoch 49/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9325 - loss: 0.7719
# Epoch 49: val_loss improved from 0.60197 to 0.59479, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9325 - loss: 0.7718 - val_accuracy: 0.9900 - val_loss: 0.5948 - learning_rate: 1.0000e-04
# Epoch 50/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9545 - loss: 0.7128
# Epoch 50: val_loss improved from 0.59479 to 0.58627, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9545 - loss: 0.7128 - val_accuracy: 0.9867 - val_loss: 0.5863 - learning_rate: 1.0000e-04
# Epoch 51/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9448 - loss: 0.7373
# Epoch 51: val_loss improved from 0.58627 to 0.57468, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9447 - loss: 0.7373 - val_accuracy: 0.9850 - val_loss: 0.5747 - learning_rate: 1.0000e-04
# Epoch 52/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9488 - loss: 0.6925
# Epoch 52: val_loss did not improve from 0.57468
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9488 - loss: 0.6926 - val_accuracy: 0.9867 - val_loss: 0.5803 - learning_rate: 1.0000e-04
# Epoch 53/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9301 - loss: 0.8097
# Epoch 53: val_loss did not improve from 0.57468
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9302 - loss: 0.8096 - val_accuracy: 0.9850 - val_loss: 0.5835 - learning_rate: 1.0000e-04
# Epoch 54/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9325 - loss: 0.7480
# Epoch 54: val_loss did not improve from 0.57468
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9326 - loss: 0.7480 - val_accuracy: 0.9883 - val_loss: 0.5755 - learning_rate: 1.0000e-04
# Epoch 55/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9226 - loss: 0.7619
# Epoch 55: val_loss improved from 0.57468 to 0.56945, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9226 - loss: 0.7618 - val_accuracy: 0.9817 - val_loss: 0.5695 - learning_rate: 1.0000e-04
# Epoch 56/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9280 - loss: 0.7615
# Epoch 56: val_loss improved from 0.56945 to 0.55880, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9280 - loss: 0.7614 - val_accuracy: 0.9850 - val_loss: 0.5588 - learning_rate: 1.0000e-04
# Epoch 57/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9558 - loss: 0.6509
# Epoch 57: val_loss did not improve from 0.55880
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9558 - loss: 0.6509 - val_accuracy: 0.9800 - val_loss: 0.5799 - learning_rate: 1.0000e-04
# Epoch 58/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9507 - loss: 0.6647
# Epoch 58: val_loss improved from 0.55880 to 0.54653, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9507 - loss: 0.6647 - val_accuracy: 0.9867 - val_loss: 0.5465 - learning_rate: 1.0000e-04
# Epoch 59/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9246 - loss: 0.7695
# Epoch 59: val_loss improved from 0.54653 to 0.53872, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9246 - loss: 0.7694 - val_accuracy: 0.9917 - val_loss: 0.5387 - learning_rate: 1.0000e-04
# Epoch 60/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9470 - loss: 0.6959
# Epoch 60: val_loss did not improve from 0.53872
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9470 - loss: 0.6959 - val_accuracy: 0.9867 - val_loss: 0.5416 - learning_rate: 1.0000e-04
# Epoch 61/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9512 - loss: 0.6816
# Epoch 61: val_loss improved from 0.53872 to 0.52911, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9511 - loss: 0.6816 - val_accuracy: 0.9917 - val_loss: 0.5291 - learning_rate: 1.0000e-04
# Epoch 62/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9424 - loss: 0.6965
# Epoch 62: val_loss improved from 0.52911 to 0.51559, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9424 - loss: 0.6964 - val_accuracy: 0.9933 - val_loss: 0.5156 - learning_rate: 1.0000e-04
# Epoch 63/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9486 - loss: 0.6598
# Epoch 63: val_loss did not improve from 0.51559
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9486 - loss: 0.6598 - val_accuracy: 0.9883 - val_loss: 0.5235 - learning_rate: 1.0000e-04
# Epoch 64/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9289 - loss: 0.7168
# Epoch 64: val_loss improved from 0.51559 to 0.50295, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9289 - loss: 0.7167 - val_accuracy: 0.9883 - val_loss: 0.5030 - learning_rate: 1.0000e-04
# Epoch 65/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9649 - loss: 0.6043
# Epoch 65: val_loss did not improve from 0.50295
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9649 - loss: 0.6044 - val_accuracy: 0.9900 - val_loss: 0.5064 - learning_rate: 1.0000e-04
# Epoch 66/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9537 - loss: 0.6521
# Epoch 66: val_loss did not improve from 0.50295
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9537 - loss: 0.6521 - val_accuracy: 0.9850 - val_loss: 0.5185 - learning_rate: 1.0000e-04
# Epoch 67/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9332 - loss: 0.6887
# Epoch 67: val_loss did not improve from 0.50295
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9332 - loss: 0.6887 - val_accuracy: 0.9917 - val_loss: 0.5065 - learning_rate: 1.0000e-04
# Epoch 68/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9449 - loss: 0.6781
# Epoch 68: val_loss improved from 0.50295 to 0.49819, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9449 - loss: 0.6781 - val_accuracy: 0.9917 - val_loss: 0.4982 - learning_rate: 1.0000e-04
# Epoch 69/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9389 - loss: 0.6866
# Epoch 69: val_loss improved from 0.49819 to 0.49294, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9389 - loss: 0.6866 - val_accuracy: 0.9900 - val_loss: 0.4929 - learning_rate: 1.0000e-04
# Epoch 70/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9422 - loss: 0.6443
# Epoch 70: val_loss improved from 0.49294 to 0.48903, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9422 - loss: 0.6443 - val_accuracy: 0.9900 - val_loss: 0.4890 - learning_rate: 1.0000e-04
# Epoch 71/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9515 - loss: 0.6176
# Epoch 71: val_loss improved from 0.48903 to 0.48894, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9515 - loss: 0.6176 - val_accuracy: 0.9850 - val_loss: 0.4889 - learning_rate: 1.0000e-04
# Epoch 72/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9416 - loss: 0.6483
# Epoch 72: val_loss improved from 0.48894 to 0.48087, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9417 - loss: 0.6482 - val_accuracy: 0.9917 - val_loss: 0.4809 - learning_rate: 1.0000e-04
# Epoch 73/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9521 - loss: 0.6289
# Epoch 73: val_loss did not improve from 0.48087
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9521 - loss: 0.6289 - val_accuracy: 0.9750 - val_loss: 0.4973 - learning_rate: 1.0000e-04
# Epoch 74/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9408 - loss: 0.6697
# Epoch 74: val_loss improved from 0.48087 to 0.48002, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9408 - loss: 0.6697 - val_accuracy: 0.9850 - val_loss: 0.4800 - learning_rate: 1.0000e-04
# Epoch 75/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9278 - loss: 0.6850
# Epoch 75: val_loss improved from 0.48002 to 0.47461, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9278 - loss: 0.6849 - val_accuracy: 0.9850 - val_loss: 0.4746 - learning_rate: 1.0000e-04
# Epoch 76/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9360 - loss: 0.6390
# Epoch 76: val_loss improved from 0.47461 to 0.47457, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9360 - loss: 0.6390 - val_accuracy: 0.9883 - val_loss: 0.4746 - learning_rate: 1.0000e-04
# Epoch 77/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9479 - loss: 0.6242
# Epoch 77: val_loss improved from 0.47457 to 0.46885, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9479 - loss: 0.6242 - val_accuracy: 0.9900 - val_loss: 0.4688 - learning_rate: 1.0000e-04
# Epoch 78/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9543 - loss: 0.5995
# Epoch 78: val_loss improved from 0.46885 to 0.45002, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9543 - loss: 0.5995 - val_accuracy: 0.9883 - val_loss: 0.4500 - learning_rate: 1.0000e-04
# Epoch 79/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9538 - loss: 0.6144
# Epoch 79: val_loss did not improve from 0.45002
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9538 - loss: 0.6144 - val_accuracy: 0.9867 - val_loss: 0.4585 - learning_rate: 1.0000e-04
# Epoch 80/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9367 - loss: 0.6349
# Epoch 80: val_loss did not improve from 0.45002
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9367 - loss: 0.6349 - val_accuracy: 0.9867 - val_loss: 0.4577 - learning_rate: 1.0000e-04
# Epoch 81/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9449 - loss: 0.6018
# Epoch 81: val_loss improved from 0.45002 to 0.44007, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9449 - loss: 0.6018 - val_accuracy: 0.9867 - val_loss: 0.4401 - learning_rate: 1.0000e-04
# Epoch 82/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9645 - loss: 0.5267
# Epoch 82: val_loss did not improve from 0.44007
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9645 - loss: 0.5267 - val_accuracy: 0.9867 - val_loss: 0.4540 - learning_rate: 1.0000e-04
# Epoch 83/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9628 - loss: 0.5400
# Epoch 83: val_loss did not improve from 0.44007
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9628 - loss: 0.5401 - val_accuracy: 0.9867 - val_loss: 0.4493 - learning_rate: 1.0000e-04
# Epoch 84/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9353 - loss: 0.6215
# Epoch 84: val_loss improved from 0.44007 to 0.42501, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9353 - loss: 0.6214 - val_accuracy: 0.9900 - val_loss: 0.4250 - learning_rate: 1.0000e-04
# Epoch 85/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9569 - loss: 0.5490
# Epoch 85: val_loss did not improve from 0.42501
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9569 - loss: 0.5490 - val_accuracy: 0.9867 - val_loss: 0.4338 - learning_rate: 1.0000e-04
# Epoch 86/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9607 - loss: 0.5102
# Epoch 86: val_loss did not improve from 0.42501
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9607 - loss: 0.5102 - val_accuracy: 0.9817 - val_loss: 0.4355 - learning_rate: 1.0000e-04
# Epoch 87/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9491 - loss: 0.5718
# Epoch 87: val_loss improved from 0.42501 to 0.42087, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9491 - loss: 0.5717 - val_accuracy: 0.9917 - val_loss: 0.4209 - learning_rate: 1.0000e-04
# Epoch 88/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9610 - loss: 0.5263
# Epoch 88: val_loss improved from 0.42087 to 0.40897, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9610 - loss: 0.5264 - val_accuracy: 0.9867 - val_loss: 0.4090 - learning_rate: 1.0000e-04
# Epoch 89/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9641 - loss: 0.5219
# Epoch 89: val_loss did not improve from 0.40897
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9642 - loss: 0.5218 - val_accuracy: 0.9883 - val_loss: 0.4099 - learning_rate: 1.0000e-04
# Epoch 90/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9602 - loss: 0.5395
# Epoch 90: val_loss did not improve from 0.40897
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9602 - loss: 0.5395 - val_accuracy: 0.9833 - val_loss: 0.4192 - learning_rate: 1.0000e-04
# Epoch 91/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9483 - loss: 0.5494
# Epoch 91: val_loss did not improve from 0.40897
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9483 - loss: 0.5494 - val_accuracy: 0.9867 - val_loss: 0.4169 - learning_rate: 1.0000e-04
# Epoch 92/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9555 - loss: 0.5409
# Epoch 92: val_loss did not improve from 0.40897
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 49ms/step - accuracy: 0.9555 - loss: 0.5409 - val_accuracy: 0.9817 - val_loss: 0.4212 - learning_rate: 1.0000e-04
# Epoch 93/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9360 - loss: 0.5508
# Epoch 93: val_loss did not improve from 0.40897
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9360 - loss: 0.5508 - val_accuracy: 0.9833 - val_loss: 0.4126 - learning_rate: 1.0000e-04
# Epoch 94/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9612 - loss: 0.5003
# Epoch 94: val_loss improved from 0.40897 to 0.39681, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9612 - loss: 0.5003 - val_accuracy: 0.9850 - val_loss: 0.3968 - learning_rate: 5.0000e-05
# Epoch 95/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9511 - loss: 0.5246
# Epoch 95: val_loss improved from 0.39681 to 0.39335, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9511 - loss: 0.5246 - val_accuracy: 0.9867 - val_loss: 0.3933 - learning_rate: 5.0000e-05
# Epoch 96/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9506 - loss: 0.5084
# Epoch 96: val_loss did not improve from 0.39335
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9506 - loss: 0.5084 - val_accuracy: 0.9883 - val_loss: 0.3952 - learning_rate: 5.0000e-05
# Epoch 97/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9465 - loss: 0.5551
# Epoch 97: val_loss did not improve from 0.39335
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9465 - loss: 0.5551 - val_accuracy: 0.9900 - val_loss: 0.3937 - learning_rate: 5.0000e-05
# Epoch 98/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9655 - loss: 0.4838
# Epoch 98: val_loss improved from 0.39335 to 0.39077, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9655 - loss: 0.4838 - val_accuracy: 0.9900 - val_loss: 0.3908 - learning_rate: 5.0000e-05
# Epoch 99/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9570 - loss: 0.5137
# Epoch 99: val_loss improved from 0.39077 to 0.38622, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9570 - loss: 0.5137 - val_accuracy: 0.9850 - val_loss: 0.3862 - learning_rate: 5.0000e-05
# Epoch 100/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9494 - loss: 0.5792
# Epoch 100: val_loss improved from 0.38622 to 0.38541, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9494 - loss: 0.5791 - val_accuracy: 0.9867 - val_loss: 0.3854 - learning_rate: 5.0000e-05
# Epoch 101/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9641 - loss: 0.4731
# Epoch 101: val_loss improved from 0.38541 to 0.38395, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9641 - loss: 0.4731 - val_accuracy: 0.9850 - val_loss: 0.3840 - learning_rate: 5.0000e-05
# Epoch 102/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9576 - loss: 0.4957
# Epoch 102: val_loss improved from 0.38395 to 0.37617, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9576 - loss: 0.4958 - val_accuracy: 0.9833 - val_loss: 0.3762 - learning_rate: 5.0000e-05
# Epoch 103/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9636 - loss: 0.4806
# Epoch 103: val_loss improved from 0.37617 to 0.37283, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9636 - loss: 0.4807 - val_accuracy: 0.9833 - val_loss: 0.3728 - learning_rate: 5.0000e-05
# Epoch 104/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9616 - loss: 0.4902
# Epoch 104: val_loss did not improve from 0.37283
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9616 - loss: 0.4903 - val_accuracy: 0.9783 - val_loss: 0.3964 - learning_rate: 5.0000e-05
# Epoch 105/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9615 - loss: 0.4792
# Epoch 105: val_loss improved from 0.37283 to 0.36509, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9615 - loss: 0.4792 - val_accuracy: 0.9867 - val_loss: 0.3651 - learning_rate: 5.0000e-05
# Epoch 106/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9619 - loss: 0.4733
# Epoch 106: val_loss improved from 0.36509 to 0.36322, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9619 - loss: 0.4733 - val_accuracy: 0.9867 - val_loss: 0.3632 - learning_rate: 5.0000e-05
# Epoch 107/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9589 - loss: 0.4692
# Epoch 107: val_loss did not improve from 0.36322
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9589 - loss: 0.4692 - val_accuracy: 0.9883 - val_loss: 0.3708 - learning_rate: 5.0000e-05
# Epoch 108/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9620 - loss: 0.4866
# Epoch 108: val_loss did not improve from 0.36322
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9620 - loss: 0.4866 - val_accuracy: 0.9883 - val_loss: 0.3636 - learning_rate: 5.0000e-05
# Epoch 109/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9658 - loss: 0.4624
# Epoch 109: val_loss improved from 0.36322 to 0.36314, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9658 - loss: 0.4624 - val_accuracy: 0.9833 - val_loss: 0.3631 - learning_rate: 5.0000e-05
# Epoch 110/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9525 - loss: 0.4900
# Epoch 110: val_loss did not improve from 0.36314
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9526 - loss: 0.4900 - val_accuracy: 0.9900 - val_loss: 0.3702 - learning_rate: 5.0000e-05
# Epoch 111/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9580 - loss: 0.4801
# Epoch 111: val_loss improved from 0.36314 to 0.35676, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9580 - loss: 0.4802 - val_accuracy: 0.9900 - val_loss: 0.3568 - learning_rate: 5.0000e-05
# Epoch 112/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9629 - loss: 0.4556
# Epoch 112: val_loss improved from 0.35676 to 0.35446, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9629 - loss: 0.4556 - val_accuracy: 0.9917 - val_loss: 0.3545 - learning_rate: 5.0000e-05
# Epoch 113/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9678 - loss: 0.4445
# Epoch 113: val_loss improved from 0.35446 to 0.35408, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9678 - loss: 0.4445 - val_accuracy: 0.9917 - val_loss: 0.3541 - learning_rate: 5.0000e-05
# Epoch 114/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9604 - loss: 0.4642
# Epoch 114: val_loss improved from 0.35408 to 0.35338, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9604 - loss: 0.4641 - val_accuracy: 0.9850 - val_loss: 0.3534 - learning_rate: 5.0000e-05
# Epoch 115/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9662 - loss: 0.4355
# Epoch 115: val_loss improved from 0.35338 to 0.34717, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9662 - loss: 0.4355 - val_accuracy: 0.9900 - val_loss: 0.3472 - learning_rate: 5.0000e-05
# Epoch 116/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9598 - loss: 0.4532
# Epoch 116: val_loss improved from 0.34717 to 0.34184, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9598 - loss: 0.4533 - val_accuracy: 0.9883 - val_loss: 0.3418 - learning_rate: 5.0000e-05
# Epoch 117/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9525 - loss: 0.5005
# Epoch 117: val_loss improved from 0.34184 to 0.33844, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9525 - loss: 0.5005 - val_accuracy: 0.9900 - val_loss: 0.3384 - learning_rate: 5.0000e-05
# Epoch 118/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9654 - loss: 0.4319
# Epoch 118: val_loss did not improve from 0.33844
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9654 - loss: 0.4320 - val_accuracy: 0.9900 - val_loss: 0.3438 - learning_rate: 5.0000e-05
# Epoch 119/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9657 - loss: 0.4542
# Epoch 119: val_loss improved from 0.33844 to 0.33717, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9657 - loss: 0.4542 - val_accuracy: 0.9883 - val_loss: 0.3372 - learning_rate: 5.0000e-05
# Epoch 120/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9671 - loss: 0.4282
# Epoch 120: val_loss did not improve from 0.33717
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9670 - loss: 0.4282 - val_accuracy: 0.9867 - val_loss: 0.3408 - learning_rate: 5.0000e-05
# Epoch 121/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9724 - loss: 0.4161
# Epoch 121: val_loss improved from 0.33717 to 0.32711, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9724 - loss: 0.4161 - val_accuracy: 0.9883 - val_loss: 0.3271 - learning_rate: 5.0000e-05
# Epoch 122/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9748 - loss: 0.3983
# Epoch 122: val_loss did not improve from 0.32711
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9748 - loss: 0.3984 - val_accuracy: 0.9900 - val_loss: 0.3271 - learning_rate: 5.0000e-05
# Epoch 123/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9580 - loss: 0.4589
# Epoch 123: val_loss did not improve from 0.32711
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9580 - loss: 0.4589 - val_accuracy: 0.9917 - val_loss: 0.3282 - learning_rate: 5.0000e-05
# Epoch 124/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9444 - loss: 0.5143
# Epoch 124: val_loss did not improve from 0.32711
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9444 - loss: 0.5142 - val_accuracy: 0.9883 - val_loss: 0.3315 - learning_rate: 5.0000e-05
# Epoch 125/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9564 - loss: 0.4366
# Epoch 125: val_loss improved from 0.32711 to 0.32166, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9564 - loss: 0.4366 - val_accuracy: 0.9883 - val_loss: 0.3217 - learning_rate: 5.0000e-05
# Epoch 126/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9629 - loss: 0.4311
# Epoch 126: val_loss improved from 0.32166 to 0.32142, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9629 - loss: 0.4311 - val_accuracy: 0.9917 - val_loss: 0.3214 - learning_rate: 5.0000e-05
# Epoch 127/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9404 - loss: 0.5009
# Epoch 127: val_loss improved from 0.32142 to 0.31839, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9404 - loss: 0.5009 - val_accuracy: 0.9917 - val_loss: 0.3184 - learning_rate: 5.0000e-05
# Epoch 128/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9657 - loss: 0.4212
# Epoch 128: val_loss did not improve from 0.31839
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9657 - loss: 0.4212 - val_accuracy: 0.9933 - val_loss: 0.3208 - learning_rate: 5.0000e-05
# Epoch 129/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9762 - loss: 0.3984
# Epoch 129: val_loss improved from 0.31839 to 0.31759, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9762 - loss: 0.3984 - val_accuracy: 0.9917 - val_loss: 0.3176 - learning_rate: 5.0000e-05
# Epoch 130/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9689 - loss: 0.3962
# Epoch 130: val_loss improved from 0.31759 to 0.31662, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9689 - loss: 0.3963 - val_accuracy: 0.9933 - val_loss: 0.3166 - learning_rate: 5.0000e-05
# Epoch 131/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9666 - loss: 0.4029
# Epoch 131: val_loss did not improve from 0.31662
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9666 - loss: 0.4030 - val_accuracy: 0.9883 - val_loss: 0.3214 - learning_rate: 5.0000e-05
# Epoch 132/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9575 - loss: 0.4394
# Epoch 132: val_loss improved from 0.31662 to 0.31376, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 50ms/step - accuracy: 0.9575 - loss: 0.4394 - val_accuracy: 0.9933 - val_loss: 0.3138 - learning_rate: 5.0000e-05
# Epoch 133/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9706 - loss: 0.3990
# Epoch 133: val_loss improved from 0.31376 to 0.30847, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9706 - loss: 0.3990 - val_accuracy: 0.9933 - val_loss: 0.3085 - learning_rate: 5.0000e-05
# Epoch 134/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9600 - loss: 0.4440
# Epoch 134: val_loss did not improve from 0.30847
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9600 - loss: 0.4440 - val_accuracy: 0.9900 - val_loss: 0.3090 - learning_rate: 5.0000e-05
# Epoch 135/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9566 - loss: 0.4492
# Epoch 135: val_loss improved from 0.30847 to 0.30581, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9566 - loss: 0.4492 - val_accuracy: 0.9917 - val_loss: 0.3058 - learning_rate: 5.0000e-05
# Epoch 136/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9694 - loss: 0.3793
# Epoch 136: val_loss did not improve from 0.30581
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9694 - loss: 0.3794 - val_accuracy: 0.9883 - val_loss: 0.3140 - learning_rate: 5.0000e-05
# Epoch 137/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9715 - loss: 0.3929
# Epoch 137: val_loss improved from 0.30581 to 0.30569, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9715 - loss: 0.3929 - val_accuracy: 0.9900 - val_loss: 0.3057 - learning_rate: 5.0000e-05
# Epoch 138/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9558 - loss: 0.4128
# Epoch 138: val_loss improved from 0.30569 to 0.30419, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9558 - loss: 0.4128 - val_accuracy: 0.9900 - val_loss: 0.3042 - learning_rate: 5.0000e-05
# Epoch 139/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9637 - loss: 0.4077
# Epoch 139: val_loss improved from 0.30419 to 0.30031, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9637 - loss: 0.4076 - val_accuracy: 0.9917 - val_loss: 0.3003 - learning_rate: 5.0000e-05
# Epoch 140/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9560 - loss: 0.4282
# Epoch 140: val_loss improved from 0.30031 to 0.29887, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9560 - loss: 0.4281 - val_accuracy: 0.9867 - val_loss: 0.2989 - learning_rate: 5.0000e-05
# Epoch 141/200
# ...
# Epoch 149/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9686 - loss: 0.3755
# Epoch 149: val_loss improved from 0.29301 to 0.29116, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9686 - loss: 0.3755 - val_accuracy: 0.9917 - val_loss: 0.2912 - learning_rate: 5.0000e-05
# Epoch 150/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9702 - loss: 0.3758
# Epoch 150: val_loss improved from 0.29116 to 0.28779, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9702 - loss: 0.3758 - val_accuracy: 0.9900 - val_loss: 0.2878 - learning_rate: 5.0000e-05
# Epoch 151/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9519 - loss: 0.4072
# Epoch 151: val_loss improved from 0.28779 to 0.28085, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9519 - loss: 0.4072 - val_accuracy: 0.9933 - val_loss: 0.2809 - learning_rate: 5.0000e-05
# Epoch 152/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9638 - loss: 0.3828
# Epoch 152: val_loss did not improve from 0.28085
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9638 - loss: 0.3828 - val_accuracy: 0.9883 - val_loss: 0.2836 - learning_rate: 5.0000e-05
# Epoch 153/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9752 - loss: 0.3546
# Epoch 153: val_loss did not improve from 0.28085
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9752 - loss: 0.3546 - val_accuracy: 0.9867 - val_loss: 0.2862 - learning_rate: 5.0000e-05
# Epoch 154/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9702 - loss: 0.3721
# Epoch 154: val_loss improved from 0.28085 to 0.28065, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9702 - loss: 0.3721 - val_accuracy: 0.9867 - val_loss: 0.2807 - learning_rate: 5.0000e-05
# Epoch 155/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9622 - loss: 0.4029
# Epoch 155: val_loss did not improve from 0.28065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9622 - loss: 0.4029 - val_accuracy: 0.9900 - val_loss: 0.2863 - learning_rate: 5.0000e-05
# Epoch 156/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9657 - loss: 0.4236
# Epoch 156: val_loss did not improve from 0.28065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9657 - loss: 0.4236 - val_accuracy: 0.9867 - val_loss: 0.2823 - learning_rate: 5.0000e-05
# Epoch 157/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9802 - loss: 0.3069
# Epoch 157: val_loss did not improve from 0.28065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9802 - loss: 0.3069 - val_accuracy: 0.9867 - val_loss: 0.2906 - learning_rate: 5.0000e-05
# Epoch 158/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9693 - loss: 0.3607
# Epoch 158: val_loss improved from 0.28065 to 0.27804, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9693 - loss: 0.3607 - val_accuracy: 0.9867 - val_loss: 0.2780 - learning_rate: 5.0000e-05
# Epoch 159/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9694 - loss: 0.3636
# Epoch 159: val_loss improved from 0.27804 to 0.27484, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9694 - loss: 0.3636 - val_accuracy: 0.9917 - val_loss: 0.2748 - learning_rate: 5.0000e-05
# Epoch 160/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9760 - loss: 0.3298
# Epoch 160: val_loss did not improve from 0.27484
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9760 - loss: 0.3298 - val_accuracy: 0.9900 - val_loss: 0.2759 - learning_rate: 5.0000e-05
# Epoch 161/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9651 - loss: 0.4044
# Epoch 161: val_loss improved from 0.27484 to 0.27095, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9651 - loss: 0.4044 - val_accuracy: 0.9900 - val_loss: 0.2710 - learning_rate: 5.0000e-05
# Epoch 162/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9648 - loss: 0.3951
# Epoch 162: val_loss did not improve from 0.27095
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9648 - loss: 0.3951 - val_accuracy: 0.9850 - val_loss: 0.2776 - learning_rate: 5.0000e-05
# Epoch 163/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9704 - loss: 0.3631
# Epoch 163: val_loss improved from 0.27095 to 0.26970, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9704 - loss: 0.3631 - val_accuracy: 0.9883 - val_loss: 0.2697 - learning_rate: 5.0000e-05
# Epoch 164/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9562 - loss: 0.4012
# Epoch 164: val_loss improved from 0.26970 to 0.26845, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9562 - loss: 0.4011 - val_accuracy: 0.9883 - val_loss: 0.2684 - learning_rate: 5.0000e-05
# Epoch 165/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9639 - loss: 0.3769
# Epoch 165: val_loss did not improve from 0.26845
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9639 - loss: 0.3769 - val_accuracy: 0.9833 - val_loss: 0.2770 - learning_rate: 5.0000e-05
# Epoch 166/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9733 - loss: 0.3541
# Epoch 166: val_loss improved from 0.26845 to 0.26629, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9733 - loss: 0.3541 - val_accuracy: 0.9883 - val_loss: 0.2663 - learning_rate: 5.0000e-05
# Epoch 167/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9773 - loss: 0.3298
# Epoch 167: val_loss improved from 0.26629 to 0.26549, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9773 - loss: 0.3298 - val_accuracy: 0.9917 - val_loss: 0.2655 - learning_rate: 5.0000e-05
# Epoch 168/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9696 - loss: 0.3503
# Epoch 168: val_loss improved from 0.26549 to 0.26342, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9696 - loss: 0.3503 - val_accuracy: 0.9883 - val_loss: 0.2634 - learning_rate: 5.0000e-05
# Epoch 169/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9735 - loss: 0.3221
# Epoch 169: val_loss did not improve from 0.26342
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9735 - loss: 0.3222 - val_accuracy: 0.9900 - val_loss: 0.2684 - learning_rate: 5.0000e-05
# Epoch 170/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9514 - loss: 0.4219
# Epoch 170: val_loss improved from 0.26342 to 0.26065, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9513 - loss: 0.4219 - val_accuracy: 0.9883 - val_loss: 0.2606 - learning_rate: 5.0000e-05
# Epoch 171/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9660 - loss: 0.3573
# Epoch 171: val_loss did not improve from 0.26065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9660 - loss: 0.3573 - val_accuracy: 0.9883 - val_loss: 0.2609 - learning_rate: 5.0000e-05
# Epoch 172/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9645 - loss: 0.3711
# Epoch 172: val_loss did not improve from 0.26065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9645 - loss: 0.3711 - val_accuracy: 0.9917 - val_loss: 0.2629 - learning_rate: 5.0000e-05
# Epoch 173/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9529 - loss: 0.3817
# Epoch 173: val_loss did not improve from 0.26065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9529 - loss: 0.3816 - val_accuracy: 0.9883 - val_loss: 0.2663 - learning_rate: 5.0000e-05
# Epoch 174/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9558 - loss: 0.3902
# Epoch 174: val_loss did not improve from 0.26065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9557 - loss: 0.3903 - val_accuracy: 0.9850 - val_loss: 0.2708 - learning_rate: 5.0000e-05
# Epoch 175/200
# 524/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9776 - loss: 0.3167
# Epoch 175: val_loss did not improve from 0.26065
#
# Epoch 175: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9776 - loss: 0.3168 - val_accuracy: 0.9850 - val_loss: 0.2836 - learning_rate: 5.0000e-05
# Epoch 176/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9678 - loss: 0.3683
# Epoch 176: val_loss did not improve from 0.26065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9678 - loss: 0.3683 - val_accuracy: 0.9850 - val_loss: 0.2680 - learning_rate: 2.5000e-05
# Epoch 177/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9577 - loss: 0.3679
# Epoch 177: val_loss did not improve from 0.26065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9577 - loss: 0.3679 - val_accuracy: 0.9883 - val_loss: 0.2636 - learning_rate: 2.5000e-05
# Epoch 178/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9621 - loss: 0.3639
# Epoch 178: val_loss did not improve from 0.26065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9621 - loss: 0.3639 - val_accuracy: 0.9883 - val_loss: 0.2648 - learning_rate: 2.5000e-05
# Epoch 179/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9718 - loss: 0.3256
# Epoch 179: val_loss improved from 0.26065 to 0.25787, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9718 - loss: 0.3257 - val_accuracy: 0.9867 - val_loss: 0.2579 - learning_rate: 2.5000e-05
# Epoch 180/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9580 - loss: 0.3729
# Epoch 180: val_loss did not improve from 0.25787
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9580 - loss: 0.3729 - val_accuracy: 0.9883 - val_loss: 0.2579 - learning_rate: 2.5000e-05
# Epoch 181/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9818 - loss: 0.2981
# Epoch 181: val_loss improved from 0.25787 to 0.25369, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9818 - loss: 0.2981 - val_accuracy: 0.9900 - val_loss: 0.2537 - learning_rate: 2.5000e-05
# Epoch 182/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9616 - loss: 0.3753
# Epoch 182: val_loss improved from 0.25369 to 0.25348, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9616 - loss: 0.3753 - val_accuracy: 0.9917 - val_loss: 0.2535 - learning_rate: 2.5000e-05
# Epoch 183/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9633 - loss: 0.3786
# Epoch 183: val_loss did not improve from 0.25348
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9633 - loss: 0.3786 - val_accuracy: 0.9900 - val_loss: 0.2538 - learning_rate: 2.5000e-05
# Epoch 184/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9542 - loss: 0.3695
# Epoch 184: val_loss did not improve from 0.25348
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9542 - loss: 0.3695 - val_accuracy: 0.9917 - val_loss: 0.2550 - learning_rate: 2.5000e-05
# Epoch 185/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9498 - loss: 0.3862
# Epoch 185: val_loss did not improve from 0.25348
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9498 - loss: 0.3861 - val_accuracy: 0.9917 - val_loss: 0.2558 - learning_rate: 2.5000e-05
# Epoch 186/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9716 - loss: 0.3146
# Epoch 186: val_loss did not improve from 0.25348
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9715 - loss: 0.3146 - val_accuracy: 0.9883 - val_loss: 0.2564 - learning_rate: 2.5000e-05
# Epoch 187/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9673 - loss: 0.3273
# Epoch 187: val_loss did not improve from 0.25348
#
# Epoch 187: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9673 - loss: 0.3273 - val_accuracy: 0.9900 - val_loss: 0.2608 - learning_rate: 2.5000e-05
# Epoch 188/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9680 - loss: 0.3304
# Epoch 188: val_loss did not improve from 0.25348
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9680 - loss: 0.3304 - val_accuracy: 0.9900 - val_loss: 0.2546 - learning_rate: 1.2500e-05
# Epoch 189/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9669 - loss: 0.3537
# Epoch 189: val_loss improved from 0.25348 to 0.25166, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9669 - loss: 0.3537 - val_accuracy: 0.9900 - val_loss: 0.2517 - learning_rate: 1.2500e-05
# Epoch 190/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9659 - loss: 0.3139
# Epoch 190: val_loss did not improve from 0.25166
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9659 - loss: 0.3139 - val_accuracy: 0.9900 - val_loss: 0.2519 - learning_rate: 1.2500e-05
# Epoch 191/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9690 - loss: 0.3472
# Epoch 191: val_loss did not improve from 0.25166
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9690 - loss: 0.3473 - val_accuracy: 0.9867 - val_loss: 0.2532 - learning_rate: 1.2500e-05
# Epoch 192/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9763 - loss: 0.3334
# Epoch 192: val_loss improved from 0.25166 to 0.25109, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9763 - loss: 0.3334 - val_accuracy: 0.9883 - val_loss: 0.2511 - learning_rate: 1.2500e-05
# Epoch 193/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9806 - loss: 0.2871
# Epoch 193: val_loss improved from 0.25109 to 0.24760, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9806 - loss: 0.2872 - val_accuracy: 0.9917 - val_loss: 0.2476 - learning_rate: 1.2500e-05
# Epoch 194/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9736 - loss: 0.3212
# Epoch 194: val_loss improved from 0.24760 to 0.24681, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.9736 - loss: 0.3213 - val_accuracy: 0.9883 - val_loss: 0.2468 - learning_rate: 1.2500e-05
# Epoch 195/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9713 - loss: 0.3074
# Epoch 195: val_loss did not improve from 0.24681
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9713 - loss: 0.3075 - val_accuracy: 0.9900 - val_loss: 0.2496 - learning_rate: 1.2500e-05
# Epoch 196/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9749 - loss: 0.3121
# Epoch 196: val_loss improved from 0.24681 to 0.24636, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9749 - loss: 0.3121 - val_accuracy: 0.9883 - val_loss: 0.2464 - learning_rate: 1.2500e-05
# Epoch 197/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9671 - loss: 0.3356
# Epoch 197: val_loss improved from 0.24636 to 0.24542, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9671 - loss: 0.3357 - val_accuracy: 0.9900 - val_loss: 0.2454 - learning_rate: 1.2500e-05
# Epoch 198/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9647 - loss: 0.3475
# Epoch 198: val_loss improved from 0.24542 to 0.24429, saving model to best_model(3).keras
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9648 - loss: 0.3475 - val_accuracy: 0.9883 - val_loss: 0.2443 - learning_rate: 1.2500e-05
# Epoch 199/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9704 - loss: 0.3304
# Epoch 199: val_loss did not improve from 0.24429
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9704 - loss: 0.3304 - val_accuracy: 0.9867 - val_loss: 0.2472 - learning_rate: 1.2500e-05
# Epoch 200/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9665 - loss: 0.3758
# Epoch 200: val_loss did not improve from 0.24429
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 26s 50ms/step - accuracy: 0.9665 - loss: 0.3758 - val_accuracy: 0.9900 - val_loss: 0.2450 - learning_rate: 1.2500e-05

# %%
# Load the best saved model
best_model = load_model(BEST_MODEL_PATH)

# %%
# Evaluate on validation set
val_loss, val_acc = best_model.evaluate(val_dataset)
print(f"Validation Accuracy: {val_acc * 100:.2f}%")
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.9930 - loss: 0.2396
# Validation Accuracy: 98.83%

# %%
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_acc) + 1)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Plot Accuracy
axs[0].plot(epochs, train_acc, 'b', label='Training Accuracy')
axs[0].plot(epochs, val_acc, 'r', label='Validation Accuracy')
axs[0].set_title('Training and Validation Accuracy')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

# Plot Loss
axs[1].plot(epochs, train_loss, 'b', label='Training Loss')
axs[1].plot(epochs, val_loss, 'r', label='Validation Loss')
axs[1].set_title('Training and Validation Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend()
plt.show()
